# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price_df = pd.read_csv('data_files/수정주가.csv', encoding='euckr')
raw_df = pd.read_excel('data_files/재무데이터 수정.xlsx')

# %%
name = [x.split('.')[0] for x in raw_df.columns]

# %%
date = raw_df.loc[0].values

# %%
raw_df
# Out:
#        Symbol Symbol Name    ROA    ROA    ROA    ROA    ROA    ROA    ROA  \
# 0         NaN         NaN  08/4Q  09/1Q  09/2Q  09/3Q  09/4Q  10/1Q  10/2Q
# 1     A005930        삼성전자   7.62   5.24   3.78   5.46   6.93   8.74  10.53
# 2     A000660      SK하이닉스      0      0      0      0      0  12.57  18.73
# 3     A068270        셀트리온   2.92   4.89   8.63    7.3  10.48  11.75  14.02
# 4     A207940    삼성바이오로직스      0      0      0      0      0      0      0
# ...       ...         ...    ...    ...    ...    ...    ...    ...    ...
# 2049  A297570   IBKS제9호스팩      0      0      0      0      0      0      0
# 2050  A279410   한화에이스스팩4호      0      0      0      0      0      0      0
# 2051  A258790   케이비제11호스팩      0      0      0      0      0      0      0
# 2052  A264290   한화에이스스팩3호      0      0      0      0      0      0      0
# 2053  A010400     우진아이엔에스      0      0      0      0      0      0      0
#
# ...

# %%
date[0] = name[0]
date[1] = name[1]

# %%
raw_df.columns = [name, date]

# %%
raw_df.index =
# Out:
#        Symbol  Symbol Name    ROA                                            \
#        Symbol  Symbol Name  08/4Q  09/1Q  09/2Q  09/3Q  09/4Q  10/1Q  10/2Q
# 0      Symbol  Symbol Name  08/4Q  09/1Q  09/2Q  09/3Q  09/4Q  10/1Q  10/2Q
# 1     A005930         삼성전자   7.62   5.24   3.78   5.46   6.93   8.74  10.53
# 2     A000660       SK하이닉스      0      0      0      0      0  12.57  18.73
# 3     A068270         셀트리온   2.92   4.89   8.63    7.3  10.48  11.75  14.02
# 4     A207940     삼성바이오로직스      0      0      0      0      0      0      0
# ...       ...          ...    ...    ...    ...    ...    ...    ...    ...
# 2049  A297570    IBKS제9호스팩      0      0      0      0      0      0      0
# 2050  A279410    한화에이스스팩4호      0      0      0      0      0      0      0
# 2051  A258790    케이비제11호스팩      0      0      0      0      0      0      0
# 2052  A264290    한화에이스스팩3호      0      0      0      0      0      0      0
# ...

# %%
raw_df.index = raw_df['Symbol']['Symbol']

# %%
price_df = price_df.drop(0)

# %%
price_df.index = pd.to_datetime(price_df['코드명'])

# %%
price_df.drop(['코드명'], axis=1, inplace=True)

# %%
# Out:
#            A000010 A000020 A000030 A000040 A000050 A000060 A000070 A000080  \
# 코드명
# 2006-01-31     NaN    3430     NaN    2317   12164    5788   57432     NaN
# 2006-02-28     NaN    3440     NaN    2279    9693    5015   55082     NaN
# 2006-03-31     NaN    3080     NaN    2039   10187    4775   58556     NaN
# 2006-04-28     NaN    5040     NaN    1918   10985    6060   62133     NaN
# 2006-05-30     NaN    5500     NaN    1332   10643    6008   57432     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2018-10-31     NaN    9050   15750     558   11850   18200   86300   15750
# 2018-11-30     NaN    9110   15650     512   11250   21200   87500   17500
# 2018-12-28     NaN    9100   15600     500   10800   21850   78500   16600
# 2019-01-31     NaN    9840   14800     528   11000   22200   83200   16900
# 2019-02-28     NaN    9800     NaN     507   11250   22100   84300   17700
#
# ...

# %%
st_index = [x for x in price_df.index if str(x).split('-')[1] == '01']

# %%
for x in price_df.index:
    print(str(x).split('-')[0])
# Out:
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2006
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2007
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2008
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2009
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2010
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2012
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2015
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# ...

# %%
st_year = 2009
ed_year = 2018
total_money = 100000000
st_columns = ['A000950', 'A101680', 'A010770', 'A008110', 'A038110', 'A277410',
       'A103230', 'A096350', 'A011300', 'A155960']
st_index = [x for x in price_df.index if str(x).split('-')[1] == '01' and int(str(x).split('-')[0]) in range(st_year, ed_year + 1)]

st_df = price_df.loc[st_index, st_columns]
st_df.index = [str(x).split('-')[0] for x in st_df.index]
st_df.fillna(0, inplace=True)
return st_df
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp\ipykernel_7044\1640012753.py", line 11
#     return st_df
#                 ^
# SyntaxError: 'return' outside function

# %%
import math
total_money = 100000000
for year in  range(st_year, ed_year+1):
    
   
    if year != st_year:
        print(f"{year} 판매")
        total_money = 0
        total_money_change = 0
        for symbol in sold_num_df.keys():
            stock_price = int(st_df.loc[str(year), symbol])
            
            old_price = old_data[symbol] * sold_num_df[symbol]
            new_price = stock_price * sold_num_df[symbol]
            total_money_change += new_price - old_price
            total_money += stock_price * sold_num_df[symbol]
            print("과거 가격 :", old_price, "현재 가격 :", new_price, "판매결과 :", new_price - old_price)
        total_money += rest_money
        print("총 판매결과 :", total_money_change, "총 금액 :", total_money)
    
    print('')
    
    if year != ed_year:
        print(f"{year} 구매")
        rest_money = 0
        stock_num = len(st_df.columns)
        split_money = total_money / stock_num
        sold_num_df = {}
        old_data = {}
        
        for symbol in st_df.columns:
            stock_price = int(st_df.loc[str(year), symbol])
            old_data[symbol] = stock_price
            if stock_price == 0:
                rest_money += split_money

                print(f"{symbol}의 주가 정보가 없습니다")
            else:
                sold_num = math.floor(split_money / stock_price)
                sold_num_df[symbol] = sold_num
                sold_price = sold_num * stock_price
                rest_money += split_money - sold_price

                
                print(f"{symbol} {stock_price}원에 {sold_num}개 구입")
        
        print("=" * 50)
# Out:
# 2009 구매
# A000950 29500원에 338개 구입
# A101680의 주가 정보가 없습니다
# A010770 1430원에 6993개 구입
# A008110 2340원에 4273개 구입
# A038110 1175원에 8510개 구입
# A277410의 주가 정보가 없습니다
# A103230의 주가 정보가 없습니다
# A096350 722원에 13850개 구입
# A011300 136원에 73529개 구입
# A155960의 주가 정보가 없습니다
# ...
# 2010 판매
# 과거 가격 : 9971000 현재 가격 : 7706400 판매결과 : -2264600
# 과거 가격 : 9999990 현재 가격 : 14265720 판매결과 : 4265730
# 과거 가격 : 9998820 현재 가격 : 13113837 판매결과 : 3115017
# 과거 가격 : 9999250 현재 가격 : 16934900 판매결과 : 6935650
# 과거 가격 : 9999700 현재 가격 : 15581250 판매결과 : 5581550
# 과거 가격 : 9999944 현재 가격 : 14852858 판매결과 : 4852914
# 총 판매결과 : 22486261 총 금액 : 122486261.0
#
# 2010 구매
# A000950 22800원에 537개 구입
# A101680 35500원에 345개 구입
# A010770 2040원에 6004개 구입
# A008110 3069원에 3991개 구입
# A038110 1990원에 6155개 구입
# A277410의 주가 정보가 없습니다
# A103230 5530원에 2214개 구입
# A096350 1125원에 10887개 구입
# A011300 202원에 60636개 구입
# A155960의 주가 정보가 없습니다
# ...
# 2011 판매
# 과거 가격 : 12243600 현재 가격 : 24916800 판매결과 : 12673200
# 과거 가격 : 12247500 현재 가격 : 11005500 판매결과 : -1242000
# ...

# %%
def finance_data_preprocessing(path):
    
    raw_data = pd.read_excel(path)
    
    big_col = list(raw_data.columns)
    for num, temp in enumerate(big_col):
        if '.' in temp:
            big_col[num] = temp.split('.')[0]
            
    small_col = list(raw_data.loc[0])
    small_col[0] = big_col[0]
    small_col[1] = big_col[1]
    
    raw_data.columns = [big_col, small_col]
    raw_data = raw_data.drop(0)
    
    raw_data.index = raw_data['Symbol']['Symbol']
    del raw_data['Symbol']
    
    return raw_data

# %%
path = 'data_files/재무데이터 수정.xlsx'

# %%
data_df = finance_data_preprocessing(path)

# %%
def small_size(data_df, date):

    date = date
    fin_df = data_df[[('시총', date), ('PER',  date), ('PBR', date), ('PSR', date), ('Symbol Name', 'Symbol Name')]]
    fin_df['시총'][date] = pd.to_numeric(fin_df['시총'][date])
    
    market_cap_quantile_series = fin_df['시총'][date].quantile(0.2)
    filtered_df = fin_df[fin_df['시총'][date] <= market_cap_quantile_series]
   
    filtered_df = filtered_df[(filtered_df['PBR'][date] >= 0.2) & (filtered_df['PER'][date] <= 0.8)]
    
    return filtered_df['PBR'][date].sort_values()[:10]

# %%
symbol_dic = {}
for i in range(14, 19):
    date = '{:02d}/1Q'.format(i)
    year = 2000 + i
    symbol_dic[year] = list(small_size(data_df, date).index)
# Out:
# C:\Users\bitcamp\anaconda3\envs\py37_env\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
symbol_dic
# Out:
# {2014: ['A078940', 'A019570', 'A044180', 'A043220', 'A042040', 'A025620'],
#  2015: ['A208140',
#   'A092300',
#   'A080440',
#   'A024850',
#   'A056000',
#   'A033600',
#   'A002420',
#   'A099410',
#   'A021880',
#   'A053060'],
#  2016: ['A002220',
#   'A198440',
#   'A101680',
#   'A071090',
#   'A006110',
#   'A007280',
#   'A096350',
#   'A073010',
#   'A064820',
#   'A075970'],
#  2017: ['A101680',
#   'A000950',
#   'A006200',
#   'A008830',
#   'A010660',
#   'A037400',
#   'A025890',
#   'A005450',
#   'A096350',
#   'A011300'],
#  2018: ['A000950',
#   'A101680',
#   'A002690',
#   'A038110',
#   'A010660',
#   'A002070',
#   'A277410',
#   'A082850',
#   'A024070',
#   'A025890']}
